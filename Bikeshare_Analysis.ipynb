# %%
import pandas as pd
from pandas.api.types import CategoricalDtype

import seaborn as sns

# Importing Necessary Python Libraries. #Prepare Phase

# %%
# Reading datasets for all 12-month data (2023) 
jan2023 = pd.read_csv("C:\\Users\\Pavithra\\Desktop\\Input\\202301-divvy-tripdata\\202301-divvy-tripdata.csv")
feb2023 = pd.read_csv("C:\\Users\\Pavithra\\Desktop\\Input\\202302-divvy-tripdata\\202302-divvy-tripdata.csv")
march2023 = pd.read_csv("C:\\Users\\Pavithra\\Desktop\\Input\\202303-divvy-tripdata\\202303-divvy-tripdata.csv")
april2023 = pd.read_csv("C:\\Users\\Pavithra\\Desktop\\Input\\202304-divvy-tripdata\\202304-divvy-tripdata.csv")
may2023 = pd.read_csv("C:\\Users\\Pavithra\\Desktop\\Input\\202305-divvy-tripdata\\202305-divvy-tripdata.csv")
june2023 = pd.read_csv("C:\\Users\\Pavithra\\Desktop\\Input\\202306-divvy-tripdata\\202306-divvy-tripdata.csv")
july2023 = pd.read_csv("C:\\Users\\Pavithra\\Desktop\\Input\\202307-divvy-tripdata\\202307-divvy-tripdata.csv")
aug2023 = pd.read_csv("C:\\Users\\Pavithra\\Desktop\\Input\\202308-divvy-tripdata\\202308-divvy-tripdata.csv")
sep2023 = pd.read_csv("C:\\Users\\Pavithra\\Desktop\\Input\\202309-divvy-tripdata\\202309-divvy-tripdata.csv")
oct2023 = pd.read_csv("C:\\Users\\Pavithra\\Desktop\\Input\\202310-divvy-tripdata\\202310-divvy-tripdata.csv")
nov2023 = pd.read_csv("C:\\Users\\Pavithra\\Desktop\\Input\\202311-divvy-tripdata\\202311-divvy-tripdata.csv")
dec2023 = pd.read_csv("C:\\Users\\Pavithra\\Desktop\\Input\\202312-divvy-tripdata\\202312-divvy-tripdata.csv")

# %%
# List of all months' data
yearly_df = [jan2023, feb2023, march2023, april2023, may2023, june2023, july2023, aug2023, sep2023, oct2023, nov2023, dec2023]
# Aggregating them into a single dataset (part of Process phase)
trip_data = pd.concat(yearly_df)
df = trip_data

# %%
trip_data
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       F96D5A74A3E41399  electric_bike  2023-01-21 20:05:42
# 1       13CB7EB698CEDB88   classic_bike  2023-01-10 15:37:36
# 2       BD88A2E670661CE5  electric_bike  2023-01-02 07:51:57
# 3       C90792D034FED968   classic_bike  2023-01-22 10:52:58
# 4       3397017529188E8A   classic_bike  2023-01-12 13:58:01
# ...                  ...            ...                  ...
# 224068  F74DF9549B504A6B  electric_bike  2023-12-07 13:15:24
# 224069  BCDA66E761CC1029   classic_bike  2023-12-08 18:42:21
# 224070  D2CF330F9C266683   classic_bike  2023-12-05 14:09:11
# 224071  3829A0D1E00EE970  electric_bike  2023-12-02 21:36:07
# 224072  A373F5B447AEA508   classic_bike  2023-12-11 13:07:46
#
#                    ended_at           start_station_name start_station_id  \
# 0       2023-01-21 20:16:33  Lincoln Ave & Fullerton Ave     TA1309000058
# 1       2023-01-10 15:46:05        Kimbark Ave & 53rd St     TA1309000037
# ...

# %%
trip_data.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  F96D5A74A3E41399  electric_bike  2023-01-21 20:05:42  2023-01-21 20:16:33
# 1  13CB7EB698CEDB88   classic_bike  2023-01-10 15:37:36  2023-01-10 15:46:05
# 2  BD88A2E670661CE5  electric_bike  2023-01-02 07:51:57  2023-01-02 08:05:11
# 3  C90792D034FED968   classic_bike  2023-01-22 10:52:58  2023-01-22 11:01:44
# 4  3397017529188E8A   classic_bike  2023-01-12 13:58:01  2023-01-12 14:13:20
#
#             start_station_name start_station_id  \
# 0  Lincoln Ave & Fullerton Ave     TA1309000058
# 1        Kimbark Ave & 53rd St     TA1309000037
# 2       Western Ave & Lunt Ave           RP-005
# 3        Kimbark Ave & 53rd St     TA1309000037
# 4        Kimbark Ave & 53rd St     TA1309000037
#
#                  end_station_name end_station_id  start_lat  start_lng  \
# 0       Hampden Ct & Diversey Ave       202480.0  41.924074 -87.646278
# ...

# %%
trip_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5719877 entries, 0 to 224072
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          object
#  3   ended_at            object
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
# dtypes: float64(4), object(9)
# memory usage: 610.9+ MB

# %%
trip_data.describe()
# Out:
#           start_lat     start_lng       end_lat       end_lng
# count  5.719877e+06  5.719877e+06  5.712887e+06  5.712887e+06
# mean   4.190288e+01 -8.764704e+01  4.190322e+01 -8.764720e+01
# std    4.505556e-02  2.733412e-02  5.444371e-02  6.919621e-02
# min    4.163000e+01 -8.794000e+01  0.000000e+00 -8.816000e+01
# 25%    4.188096e+01 -8.766000e+01  4.188103e+01 -8.766027e+01
# 50%    4.189902e+01 -8.764403e+01  4.190000e+01 -8.764410e+01
# 75%    4.193000e+01 -8.762991e+01  4.193000e+01 -8.763000e+01
# max    4.207000e+01 -8.746000e+01  4.218000e+01  0.000000e+00

# %%
# Changing data type for date columns
trip_data['started_at'] = pd.to_datetime(trip_data['started_at'])
trip_data['ended_at'] = pd.to_datetime(trip_data['ended_at'])

# %%
trip_data.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  F96D5A74A3E41399  electric_bike 2023-01-21 20:05:42 2023-01-21 20:16:33
# 1  13CB7EB698CEDB88   classic_bike 2023-01-10 15:37:36 2023-01-10 15:46:05
# 2  BD88A2E670661CE5  electric_bike 2023-01-02 07:51:57 2023-01-02 08:05:11
# 3  C90792D034FED968   classic_bike 2023-01-22 10:52:58 2023-01-22 11:01:44
# 4  3397017529188E8A   classic_bike 2023-01-12 13:58:01 2023-01-12 14:13:20
#
#             start_station_name start_station_id  \
# 0  Lincoln Ave & Fullerton Ave     TA1309000058
# 1        Kimbark Ave & 53rd St     TA1309000037
# 2       Western Ave & Lunt Ave           RP-005
# 3        Kimbark Ave & 53rd St     TA1309000037
# 4        Kimbark Ave & 53rd St     TA1309000037
#
#                  end_station_name end_station_id  start_lat  start_lng  \
# 0       Hampden Ct & Diversey Ave       202480.0  41.924074 -87.646278
# 1         Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# ...

# %%
#Checking if the end date falls ahead of the start date
false_date = trip_data.loc[trip_data['started_at'] > trip_data['ended_at']]
# (No. of rows with false date, No. of coloumns)
false_date.shape
# Out:
# (272, 13)

# %%
#Rows with false dates being removed
td_clean = trip_data.drop(false_date.index.tolist())

# %%
# Checking for duplicates
td_clean.duplicated().sum()
# Out:
# 0

# %%
# Looking into missing values
td_clean.isnull().sum()
# Out:
# ride_id                    0
# rideable_type              0
# started_at                 0
# ended_at                   0
# start_station_name    875315
# start_station_id      875447
# end_station_name      928832
# end_station_id        928973
# start_lat                  0
# start_lng                  0
# end_lat                 6987
# end_lng                 6987
# member_casual              0
# dtype: int64

# %%
#Dropping the null values
td_dropna = td_clean.dropna()

# Viewing (No. of rows after dropping, No. of coloumns)
td_dropna.shape
# Out:
# (4330187, 13)

# %%
td_clean.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  F96D5A74A3E41399  electric_bike 2023-01-21 20:05:42 2023-01-21 20:16:33
# 1  13CB7EB698CEDB88   classic_bike 2023-01-10 15:37:36 2023-01-10 15:46:05
# 2  BD88A2E670661CE5  electric_bike 2023-01-02 07:51:57 2023-01-02 08:05:11
# 3  C90792D034FED968   classic_bike 2023-01-22 10:52:58 2023-01-22 11:01:44
# 4  3397017529188E8A   classic_bike 2023-01-12 13:58:01 2023-01-12 14:13:20
#
#             start_station_name start_station_id  \
# 0  Lincoln Ave & Fullerton Ave     TA1309000058
# 1        Kimbark Ave & 53rd St     TA1309000037
# 2       Western Ave & Lunt Ave           RP-005
# 3        Kimbark Ave & 53rd St     TA1309000037
# 4        Kimbark Ave & 53rd St     TA1309000037
#
#                  end_station_name end_station_id  start_lat  start_lng  \
# 0       Hampden Ct & Diversey Ave       202480.0  41.924074 -87.646278
# 1         Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# ...

# %%
#Converting months into seasons
def conv_seasons(month):
    if(month>=3) and (month<=5):
        return 'Spring'
    elif(month>=6) and (month<=8):
        return 'Summer'
    elif(month>=9) and (month<=11):
        return 'Autumn'
    else:
        return 'Winter'

# %%
# Assigning datetime as weekday col (Monday = 0, Sunday = 6)
td_clean['weekday'] = td_clean['started_at'].dt.dayofweek

# %%
td_clean.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  F96D5A74A3E41399  electric_bike 2023-01-21 20:05:42 2023-01-21 20:16:33
# 1  13CB7EB698CEDB88   classic_bike 2023-01-10 15:37:36 2023-01-10 15:46:05
# 2  BD88A2E670661CE5  electric_bike 2023-01-02 07:51:57 2023-01-02 08:05:11
# 3  C90792D034FED968   classic_bike 2023-01-22 10:52:58 2023-01-22 11:01:44
# 4  3397017529188E8A   classic_bike 2023-01-12 13:58:01 2023-01-12 14:13:20
#
#             start_station_name start_station_id  \
# 0  Lincoln Ave & Fullerton Ave     TA1309000058
# 1        Kimbark Ave & 53rd St     TA1309000037
# 2       Western Ave & Lunt Ave           RP-005
# 3        Kimbark Ave & 53rd St     TA1309000037
# 4        Kimbark Ave & 53rd St     TA1309000037
#
#                  end_station_name end_station_id  start_lat  start_lng  \
# 0       Hampden Ct & Diversey Ave       202480.0  41.924074 -87.646278
# 1         Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# ...

# %%
#Caluclating trip duration in minutes
td_clean['trip_duration_minutes'] = round((td_clean['ended_at']-td_clean['started_at']).dt.total_seconds()/60,2)

# %%
td_clean.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  F96D5A74A3E41399  electric_bike 2023-01-21 20:05:42 2023-01-21 20:16:33
# 1  13CB7EB698CEDB88   classic_bike 2023-01-10 15:37:36 2023-01-10 15:46:05
# 2  BD88A2E670661CE5  electric_bike 2023-01-02 07:51:57 2023-01-02 08:05:11
# 3  C90792D034FED968   classic_bike 2023-01-22 10:52:58 2023-01-22 11:01:44
# 4  3397017529188E8A   classic_bike 2023-01-12 13:58:01 2023-01-12 14:13:20
#
#             start_station_name start_station_id  \
# 0  Lincoln Ave & Fullerton Ave     TA1309000058
# 1        Kimbark Ave & 53rd St     TA1309000037
# 2       Western Ave & Lunt Ave           RP-005
# 3        Kimbark Ave & 53rd St     TA1309000037
# 4        Kimbark Ave & 53rd St     TA1309000037
#
#                  end_station_name end_station_id  start_lat  start_lng  \
# 0       Hampden Ct & Diversey Ave       202480.0  41.924074 -87.646278
# 1         Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# ...

# %%
# Extracting season
td_clean['season'] = td_clean['started_at'].dt.month.map(conv_seasons)

# %%
td_clean.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  F96D5A74A3E41399  electric_bike 2023-01-21 20:05:42 2023-01-21 20:16:33
# 1  13CB7EB698CEDB88   classic_bike 2023-01-10 15:37:36 2023-01-10 15:46:05
# 2  BD88A2E670661CE5  electric_bike 2023-01-02 07:51:57 2023-01-02 08:05:11
# 3  C90792D034FED968   classic_bike 2023-01-22 10:52:58 2023-01-22 11:01:44
# 4  3397017529188E8A   classic_bike 2023-01-12 13:58:01 2023-01-12 14:13:20
#
#             start_station_name start_station_id  \
# 0  Lincoln Ave & Fullerton Ave     TA1309000058
# 1        Kimbark Ave & 53rd St     TA1309000037
# 2       Western Ave & Lunt Ave           RP-005
# 3        Kimbark Ave & 53rd St     TA1309000037
# 4        Kimbark Ave & 53rd St     TA1309000037
#
#                  end_station_name end_station_id  start_lat  start_lng  \
# 0       Hampden Ct & Diversey Ave       202480.0  41.924074 -87.646278
# 1         Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# ...

# %%
#Replacing weekday numbers with its names
Weekday_names = {0:'Monday', 1:'Tuesday', 2:'Wednesday', 3:'Thursday', 4:'Friday', 5:'Saturday', 6:'Sunday'}
td_clean['Weekday'] = td_clean['weekday'].map(Weekday_names)

# %%
td_clean.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  F96D5A74A3E41399  electric_bike 2023-01-21 20:05:42 2023-01-21 20:16:33
# 1  13CB7EB698CEDB88   classic_bike 2023-01-10 15:37:36 2023-01-10 15:46:05
# 2  BD88A2E670661CE5  electric_bike 2023-01-02 07:51:57 2023-01-02 08:05:11
# 3  C90792D034FED968   classic_bike 2023-01-22 10:52:58 2023-01-22 11:01:44
# 4  3397017529188E8A   classic_bike 2023-01-12 13:58:01 2023-01-12 14:13:20
#
#             start_station_name start_station_id  \
# 0  Lincoln Ave & Fullerton Ave     TA1309000058
# 1        Kimbark Ave & 53rd St     TA1309000037
# 2       Western Ave & Lunt Ave           RP-005
# 3        Kimbark Ave & 53rd St     TA1309000037
# 4        Kimbark Ave & 53rd St     TA1309000037
#
#                  end_station_name end_station_id  start_lat  start_lng  \
# 0       Hampden Ct & Diversey Ave       202480.0  41.924074 -87.646278
# 1         Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# ...

# %%
# Replace 'cleaned_data.csv' with the desired filename

td_clean.to_csv('cleaned_data.csv', index=False)

# %%
#Count the rides; given the user type
td_usertype = td_clean['member_casual'].value_counts().rename_axis('member_casual').reset_index(name = 'count')

# %%
#Starting Analysis based on the Ask
td_usertype
# Out:
#   member_casual    count
# 0        member  3659398
# 1        casual  2058347

# %%
#Calculating the mean of the trip duration
mean_trip_duration = td_clean['trip_duration_minutes'].mean()
print("Mean Trip Duration:", mean_trip_duration)
# Out:
# Mean Trip Duration: 18.184462138482914

# %%
# Calculating the maximum ride length
max_trip_duration_row = td_clean[td_clean['trip_duration_minutes'] == max_trip_duration_minutes]
print("Row with Maximum Trip Duration:")
print(max_trip_duration_row)
# Out:
# Row with Maximum Trip Duration:
#                  ride_id rideable_type          started_at  \
# 747619  992B647C22E22513   docked_bike 2023-08-02 19:27:12
#
#                   ended_at           start_station_name start_station_id  \
# 747619 2023-10-10 04:56:16  Campbell Ave & Montrose Ave            15623
#
#        end_station_name end_station_id  start_lat  start_lng  end_lat  \
# 747619              NaN            NaN  41.961484 -87.692321      NaN
#
#         end_lng member_casual  weekday  trip_duration_minutes  season  \
# 747619      NaN        casual        2               98489.07  Summer
#
#           Weekday
# 747619  Wednesday

# %%
max_trip_duration_row = td_clean[td_clean['trip_duration_minutes'] == max_trip_duration_minutes]
print("Row with Maximum Trip Duration:")
print(max_trip_duration_row)
# Out:
# Row with Maximum Trip Duration:
#                  ride_id rideable_type          started_at  \
# 747619  992B647C22E22513   docked_bike 2023-08-02 19:27:12
#
#                   ended_at           start_station_name start_station_id  \
# 747619 2023-10-10 04:56:16  Campbell Ave & Montrose Ave            15623
#
#        end_station_name end_station_id  start_lat  start_lng  end_lat  \
# 747619              NaN            NaN  41.961484 -87.692321      NaN
#
#         end_lng member_casual  weekday  trip_duration_minutes  season  \
# 747619      NaN        casual        2               98489.07  Summer
#
#           Weekday
# 747619  Wednesday

# %%
# Find the index of the row where the maximum value occurs in the trip_duration_minutes column
max_trip_duration_index = td_clean[td_clean['trip_duration_minutes'] == max_trip_duration_minutes].index
# Drop the row using its index
td_clean = td_clean.drop(max_trip_duration_index)
# Verify that the row has been dropped
print("Row with maximum trip duration dropped.")
# Out:
# Row with maximum trip duration dropped.

# %%
# Calculating the maximum ride length
max_trip_duration_row = td_clean[td_clean['trip_duration_minutes'] == max_trip_duration_minutes]
print("Row with Maximum Trip Duration:")
print(max_trip_duration_row)
# Out:
# Row with Maximum Trip Duration:
# Empty DataFrame
# Columns: [ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual, weekday, trip_duration_minutes, season, Weekday]
# Index: []

# %%
td_clean.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  F96D5A74A3E41399  electric_bike 2023-01-21 20:05:42 2023-01-21 20:16:33
# 1  13CB7EB698CEDB88   classic_bike 2023-01-10 15:37:36 2023-01-10 15:46:05
# 2  BD88A2E670661CE5  electric_bike 2023-01-02 07:51:57 2023-01-02 08:05:11
# 3  C90792D034FED968   classic_bike 2023-01-22 10:52:58 2023-01-22 11:01:44
# 4  3397017529188E8A   classic_bike 2023-01-12 13:58:01 2023-01-12 14:13:20
#
#             start_station_name start_station_id  \
# 0  Lincoln Ave & Fullerton Ave     TA1309000058
# 1        Kimbark Ave & 53rd St     TA1309000037
# 2       Western Ave & Lunt Ave           RP-005
# 3        Kimbark Ave & 53rd St     TA1309000037
# 4        Kimbark Ave & 53rd St     TA1309000037
#
#                  end_station_name end_station_id  start_lat  start_lng  \
# 0       Hampden Ct & Diversey Ave       202480.0  41.924074 -87.646278
# 1         Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# ...

# %%
#Converting the trip duration to minutes
td_clean['trip_duration_minutes'] = round((td_clean['ended_at'] - td_clean['started_at']).dt.total_seconds() / 60, 2)

# %%
td_clean.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  F96D5A74A3E41399  electric_bike 2023-01-21 20:05:42 2023-01-21 20:16:33
# 1  13CB7EB698CEDB88   classic_bike 2023-01-10 15:37:36 2023-01-10 15:46:05
# 2  BD88A2E670661CE5  electric_bike 2023-01-02 07:51:57 2023-01-02 08:05:11
# 3  C90792D034FED968   classic_bike 2023-01-22 10:52:58 2023-01-22 11:01:44
# 4  3397017529188E8A   classic_bike 2023-01-12 13:58:01 2023-01-12 14:13:20
#
#             start_station_name start_station_id  \
# 0  Lincoln Ave & Fullerton Ave     TA1309000058
# 1        Kimbark Ave & 53rd St     TA1309000037
# 2       Western Ave & Lunt Ave           RP-005
# 3        Kimbark Ave & 53rd St     TA1309000037
# 4        Kimbark Ave & 53rd St     TA1309000037
#
#                  end_station_name end_station_id  start_lat  start_lng  \
# 0       Hampden Ct & Diversey Ave       202480.0  41.924074 -87.646278
# 1         Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# ...

# %%
td_clean.drop(columns=['duration_minutes'], inplace=True)

# %%
td_clean.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  F96D5A74A3E41399  electric_bike 2023-01-21 20:05:42 2023-01-21 20:16:33
# 1  13CB7EB698CEDB88   classic_bike 2023-01-10 15:37:36 2023-01-10 15:46:05
# 2  BD88A2E670661CE5  electric_bike 2023-01-02 07:51:57 2023-01-02 08:05:11
# 3  C90792D034FED968   classic_bike 2023-01-22 10:52:58 2023-01-22 11:01:44
# 4  3397017529188E8A   classic_bike 2023-01-12 13:58:01 2023-01-12 14:13:20
#
#             start_station_name start_station_id  \
# 0  Lincoln Ave & Fullerton Ave     TA1309000058
# 1        Kimbark Ave & 53rd St     TA1309000037
# 2       Western Ave & Lunt Ave           RP-005
# 3        Kimbark Ave & 53rd St     TA1309000037
# 4        Kimbark Ave & 53rd St     TA1309000037
#
#                  end_station_name end_station_id  start_lat  start_lng  \
# 0       Hampden Ct & Diversey Ave       202480.0  41.924074 -87.646278
# 1         Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# ...

# %%
# Count the rides; given both user, and bike type
td_user_bike = td_clean.groupby(['member_casual','rideable_type'])['ride_id'].count().rename_axis(['member_casual', 'rideable_type']).reset_index(name = 'count')
td_user_bike
# Out:
#   member_casual  rideable_type    count
# 0        casual   classic_bike   876546
# 1        casual    docked_bike    78260
# 2        casual  electric_bike  1103539
# 3        member   classic_bike  1818508
# 4        member  electric_bike  1840890

# %%
#Count the no. of rides based on rider type and days of week
td_day_riders = td_clean.groupby(['member_casual', 'Weekday'])['weekday'].count().rename_axis(['member_casual', 'weekday']).reset_index(name = 'count')
td_day_riders
# Out:
#    member_casual    weekday   count
# 0         casual     Friday  311816
# 1         casual     Monday  234746
# 2         casual   Saturday  410557
# 3         casual     Sunday  335546
# 4         casual   Thursday  270494
# 5         casual    Tuesday  246124
# 6         casual  Wednesday  249062
# 7         member     Friday  531417
# 8         member     Monday  494391
# 9         member   Saturday  472703
# 10        member     Sunday  408689
# 11        member   Thursday  589402
# 12        member    Tuesday  576558
# 13        member  Wednesday  586238

# %%
#Average ride duration based on rider type, and weekday
Avg_day_rider = td_clean.groupby(['member_casual', 'Weekday'])['trip_duration_minutes'].mean().rename_axis(['member_casual', 'weekday']).reset_index(name = 'avg_duration_min')
# Avg duration rounded to 2 decimal points
Avg_day_rider['avg_duration_min'] = round(Avg_day_rider['avg_duration_min'], 2)
Avg_day_rider
# Out:
#    member_casual    weekday  avg_duration_min
# 0         casual     Friday             27.27
# 1         casual     Monday             27.72
# 2         casual   Saturday             32.14
# 3         casual     Sunday             32.86
# 4         casual   Thursday             24.71
# 5         casual    Tuesday             25.09
# 6         casual  Wednesday             23.88
# 7         member     Friday             12.48
# 8         member     Monday             11.90
# 9         member   Saturday             13.94
# 10        member     Sunday             13.99
# 11        member   Thursday             12.02
# 12        member    Tuesday             12.01
# 13        member  Wednesday             11.95

# %%
#Share phase
import matplotlib.pyplot as plt

# %%
def chart_custom(chart):
    sns.set_style('whitegrid')
    sns.set_context('talk')
    sns.set_palette(['#BC5090', '#FFA600'])
    chart
    plt.ticklabel_format(style='plain', axis='y')
    plt.show()

# %%
#Count the rides; given the user type
td = plt.pie(td_usertype['count'], labels=td_usertype['member_casual'], autopct='%.0f%%',
            startangle=90, colors = ['#58508D', '#FFA600'])
plt.title('% of rides for each user type')
chart_cust(td)

# %%
# Average ride duration; given user, and weekday
td = sns.barplot(data=Avg_day_rider, x='weekday', y='avg_duration_min', hue='member_casual', hue_order=['member', 'casual'])
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left')
plt.xticks(rotation=45)
plt.title('Average ride duration given weekday', fontsize=20, pad=15)
plt.xlabel('')
plt.ylabel('Avg duration')
chart_cust(td)

# %%
# Count the rides; given both user, and weekday
td = sns.barplot(data=td_day_riders, x='weekday', y='count', hue='member_casual', hue_order=['member', 'casual'])
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left')
plt.xticks(rotation=45)
plt.title('The number of rides provided on weekdays', fontsize=15, pad=20)
plt.xlabel('')
plt.ylabel('The number of rides')
chart_cust(td)

# %%
# Count the rides; given both user, and season
td_usertype_season = td_clean.groupby(['member_casual', 'season'])['season'].count().rename_axis(['member_casual', 'season']).reset_index(name = 'count')
td_usertype_season
# Out:
#   member_casual  season    count
# 0        casual  Autumn   536853
# 1        casual  Spring   443495
# 2        casual  Summer   943351
# 3        casual  Winter   134646
# 4        member  Autumn  1028532
# 5        member  Spring   846107
# 6        member  Summer  1314810
# 7        member  Winter   469949

# %%
# Visualization
td = sns.barplot(data=td_usertype_season, x='season', y='count', hue='member_casual', hue_order=['member', 'casual'])
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left')
plt.title('The number of rides for each season', fontsize=9, pad=10)
plt.xlabel('')
plt.ylabel('The Number of rides')
chart_cust(td)
